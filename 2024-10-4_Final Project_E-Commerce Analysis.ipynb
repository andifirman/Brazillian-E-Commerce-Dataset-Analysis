# %% [markdown]
# # Proyek Analisis Data: Public E-Commerce Analysis
# - **Nama:** Andi Firmansyah
# - **Email:** andi13firman@gmail.com
# - **ID Dicoding:** andifirmansy

# %% [markdown]
# # Pendahuluan

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis
# 1. Produk manakah yang paling laris di pasaran sehingga dapat memberikan keuntungan yang banyak bagi perusahaan?
# 2. Lokasi mana yang paling sering mendatangkan pelanggan yang berbelanja? Berapa keuntungan yang dihasilkan dari lokasi tersebut?

# %% [markdown]
# ## Menyiapkan Semua Packages/Library yang Digunakan
#
# Untuk memudahkan kita dalam melakukan analisis, python menyediakan beberapa library atau alat bantu yang dapat membuat analisis dapat dilakukan dengan lebih mudah. Berikut adalah beberapa library yang digunakan dalam analisis data "Public E-Commerce".
# - Library os: digunakan untuk mendapatkan path/alamat tempat dataset disimpan pada penyimpanan lokal.
# - Library numpy:
# - Library pandas:
# - Library matplotlib:
# - Library seaborn:

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Data Wrangling

# %% [markdown]
# ### 1.1 Gathering Data

# %% [markdown]
# #### 1.1.1 Menggunakan Import Dataset Online

# %% [markdown]
# #### 1.1.2 Menggunakan Dataset yang Disimpan Secara Lokal

# %%
dir = os.getcwd()

# %%
customers_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\geolocation_dataset.csv")
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\order_payments_dataset.csv")
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\order_reviews_dataset.csv")
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_category_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\product_category_name_translation.csv")
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
product_category_translate_df = pd.read_csv(dir + "\Datasets\E-Commerce Public Dataset\product_category_name_translation.csv")
product_category_translate_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ### 1.2 Assesing Data

# %% [markdown]
# #### 1.2.1 Tabel customers_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah data duplikat pada tabel customers_df:", customers_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada tabel customers_df: 0

# %% [markdown]
# #### 1.2.2 Tabel geolocation_df

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print("Jumlah data duplikat pada tabel geolocation_df: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada tabel geolocation_df:  261831

# %%
print("Atribut yang terdapat data duplikat: ", geolocation_df[geolocation_df.duplicated()])
# Out:
# Atribut yang terdapat data duplikat:           geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 15                              1046       -23.546081       -46.644820
# 44                              1046       -23.546081       -46.644820
# 65                              1046       -23.546081       -46.644820
# 66                              1009       -23.546935       -46.636588
# 67                              1046       -23.546081       -46.644820
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# ...

# %% [markdown]
# #### 1.2.3 Tabel order_items_df

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# Jika kita lihat terdapat atribut dengan tipe data yang kurang tepat yaitu shipping_limit_date di mana atribut tersebut memiliki data dengan tipe data **timestamp**, namun jika dilihat pada dataset tipe data dari atribut tersebut adalah **object** sehingga perlu diubah menjadi tipe data yang seharusnya.

# %%
order_items_df["shipping_limit_date"] = pd.to_datetime(order_items_df["shipping_limit_date"])

# %% [markdown]
# Periksa kembali tipe data yang telah diubah dari object menjadi datetime untuk memastikan attribut telah memiliki tipe data yang benar.

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah data duplikat pada tabel order_items_df:", order_items_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada tabel order_items_df: 0

# %% [markdown]
# #### 1.2.4 Tabel order_payments_df

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
print("Jumlah duplikasi pada tabel order_payments_df:", order_payments_df.duplicated().sum())
# Out:
# Jumlah duplikasi pada tabel order_payments_df: 0

# %%
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# #### 1.2.5 Tabel order_reviews_df

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# Jika kita lihat terdapat beberapa atribut dengan tipe data yang kurang tepat yaitu:
# - review_creation_date
# - review_answer_timestamp
#
# Kedua atribut tersebut memiliki data dengan tipe data **timestamp** dan **date**, namun jika dilihat pada dataset tipe data dari kelima atribut tersebut adalah **object** sehingga perlu diubah menjadi tipe data yang seharusnya.

# %%
# Fungsi untuk mengubah tipe data suatu atribut menjadi date
order_reviews_df["review_creation_date"] = pd.to_datetime(order_reviews_df["review_creation_date"]).dt.normalize()

# Fungsi untuk mengubah tipe data suatu atribut menjadi datetime 
order_reviews_df["review_answer_timestamp"] = pd.to_datetime(order_reviews_df["review_answer_timestamp"])

# %% [markdown]
# Periksa kembali tipe data yang telah diubah dari object menjadi datetime untuk memastikan attribut telah memiliki tipe data yang benar.

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print("Jumlah data duplikat pada order_reviews_df:", order_reviews_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada order_reviews_df: 0

# %% [markdown]
# #### 1.2.6 Tabel order_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Jika kita lihat terdapat beberapa atribut dengan tipe data yang kurang tepat yaitu:
# - order_purchase_timestamp
# - order_approved_at
# - order_delivered_carrier_date
# - order_delivered_customer_date
# - order_estimated_delivery_date
#
# Kelima atribut tersebut memiliki data dengan tipe data **timestamp**, namun jika dilihat pada dataset tipe data dari kelima atribut tersebut adalah **object** sehingga perlu diubah menjadi tipe data yang seharusnya.

# %%
convert_to_datetime = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in convert_to_datetime:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %% [markdown]
# Periksa kembali tipe data yang telah diubah dari object menjadi datetime untuk memastikan attribut telah memiliki tipe data yang benar.

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah data duplikat pada orders_df:", orders_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada orders_df: 0

# %% [markdown]
# #### 1.2.7 Tabel product_category_df

# %%
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_category_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("Jumlah data duplikat pada product_category_df:", product_category_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada product_category_df: 0

# %%
product_category_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# #### 1.2.8 Tabel products_df

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Jika dilihat pada atribut nomor 2 dan nomor 3 terdapat kesalahan ejaan pada kata **lenght** yang seharusnya adalah **length**. Hal ini dikhawatirkan menimbulkan kesalahpahaman sehingga kita perlu mengubah nama kedua kolom tersebut.

# %%
products_df.rename(
    columns={
        "product_name_lenght":"product_name_length", 
        "product_description_lenght": "product_description_length"
    }, inplace=True
)

# %%
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_length  product_description_length  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_length           610
# product_description_length    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah data duplikat pada products_df:", products_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada products_df: 0

# %% [markdown]
# #### 1.2.9 Tabel sellers_df

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print("Jumlah data duplikat pada tabel sellers_df:", sellers_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada tabel sellers_df: 0

# %% [markdown]
# #### 1.2.9 Tabel sellers_df

# %%
product_category_translate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_category_translate_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("Jumlah data duplikat pada tabel product_category_translate_df:", product_category_translate_df.duplicated().sum())
# Out:
# Jumlah data duplikat pada tabel product_category_translate_df: 0

# %% [markdown]
# ### 1.3 Cleaning Data

# %% [markdown]
# #### 1.3.1 Proses Cleaning Pada Tabel geolocation_df
#
# Seperti yang diketahui bahwa terdapat duplikasi data pada tabel geolocation_df sebanyak 261.831 data. Namun jika dilihat lebih lanjut, data yang duplikat terdapat pada atribut geolocation_state, geolocation_city, dan sebagainya di mana data tersebut mengandung informasi mengenai nama kota dan negara bagian sehingga data tersebut **tidak perlu dihapus** karena duplikasi terjadi bukan karena human error.

# %% [markdown]
# #### 1.3.2 Proses Cleaning Pada Tabel order_reviews_df
#
# Selanjutnya adalah proses cleaning pada tabel order_reviews_df. Seperti yang diketahui bahwa terdapat beberapa hal yang memerlukan perhatian khusus pada tabel ini, di antaranya adalah sebagai berikut.
# - Terdapat data kosong pada atribut review_comment_title sebanyak 87.656 data
# - Terdapat data kosong pada atribut review_comment_message sebanyak 58.247 data
#
#
# Data yang kosong terdapat pada atribut 'review_comment_title' dan 'review_comment_message'. Jika diperhatikan maka mungkin hal ini tidak akan terlalu berpengaruh namun kita tetap perlu mengatasi data kosong tersebut. Karena data tidak memiliki pengaruh yang begitu signifikan maka dapat diatasi dengan metode **Imputation** dengan value **No Comment**.

# %%
# Menghitung jumlah review_comment_title yang kosong berdasarkan skor review

order_reviews_df.groupby(by="review_score").agg({
    "review_comment_title": lambda x: x.isnull().sum()
})
# Out:
#               review_comment_title
# review_score
# 1                             9551
# 2                             2673
# 3                             7355
# 4                            17407
# 5                            50670

# %%
# Menghitung jumlah review_comment_message yang kosong berdasarkan skor review

order_reviews_df.groupby(by="review_score").agg({
    "review_comment_message": lambda x: x.isnull().sum()
})
# Out:
#               review_comment_message
# review_score
# 1                               2679
# 2                               1006
# 3                               4622
# 4                              13166
# 5                              36774

# %%
order_reviews_df.fillna(value="No Comment", inplace=True)

# %% [markdown]
# Setelah melakukan imputation, kita dapat memeriksa kembali apakah masih terdapat nilai kosong pada order_reviews_df.

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# #### 1.3.3 Proses Cleaning Pada Tabel orders_df
#
# Pada tabel orders_df terdapat data kosong, di antaranya adalah sebagai berikut.
# - Terdapat data kosong pada atribut order_approved_at sebanyak 160 data
# - Terdapat data kosong pada atribut order_delivered_carrier_date sebanyak 1783 data
# - Terdapat data kosong pada atribut order_delivered_customer_date sebanyak 2965 data
#
# Namun jika dilihat lebih detail lagi, ketiga atribut tersebut tidak akan berpengaruh langsung pada dataset jika dibandingkan dengan atribut lain seperti atribut **order_status** yang memuat status dari sebuah paket.

# %%
orders_df.groupby(by="order_status").agg({
    "order_id": "count"
})
# Out:
#               order_id
# order_status
# approved             2
# canceled           625
# created              5
# delivered        96478
# invoiced           314
# processing         301
# shipped           1107
# unavailable        609

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_length         32341 non-null  float64
#  3   product_description_length  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# #### 1.3.3 Proses Cleaning Pada Tabel products_df
#
# Pada tabel orders_df terdapat data kosong, di antaranya adalah sebagai berikut.
# - Terdapat data kosong pada atribut product_category_name sebanyak 610 data
# - Terdapat data kosong pada atribut product_name_length sebanyak 610 data
# - Terdapat data kosong pada atribut product_description_length sebanyak 610 data
# - Terdapat data kosong pada atribut product_photos_qty sebanyak 610 data
# - Terdapat data kosong pada atribut product_weight_g sebanyak 2 data
# - Terdapat data kosong pada atribut product_length_cm sebanyak 2 data
# - Terdapat data kosong pada atribut product_height_cm sebanyak 2 data
# - Terdapat data kosong pada atribut product_width_cm sebanyak 2 data
#
# Hal pertama yang dapat dilakukan terhadap tabel ini adalah menghapus beberapa atribut yang tidak begitu memberikan insight ketika dianalisis, di antaranya adalah atribut berikut.
# - Atribut product_name_length
# - Atribut product_description_length
# - Atribut product_photos_qty
# - Atribut product_weight_g
# - Atribut product_length_cm
# - Atribut product_height_cm
# - Atribut product_width_cm

# %%
column_to_drop = ["product_name_length", "product_description_length", "product_photos_qty", "product_weight_g", "product_length_cm", "product_height_cm", "product_width_cm"]

for column in column_to_drop:
    products_df.drop(column, axis=1, inplace=True)

# %%
products_df.head()
# Out:
#                          product_id  product_category_name
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas

# %% [markdown]
# Setelah menghapus atribut yang tidak diperlukan, selanjutnya adalah menangani data kosong yang terdapat pada dataset products_df. Jika diingat kembali terdapat sebanyak 610 data kosong pada atribut product_category_name. Itu artinya terdapat 0.0185% data yang bernilai kosong (NULL). Untuk menangani data ini kita dapat mengabaikannya saja karena atribut product_category_name bukan merupakan atribut yang berperan sebagai _primary key_.

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 2.1 Explore Tabel customers_df
#
# Seperti yang diketahui bahwa tabel customers_df memuat banyak informasi yang berkaitan dengan customer. Sebagai langkah awal dalam melakukan exploratory data analysis kita akan melihat ringkasan statistik dari tabel customers_df dengan menggunakan fungsi describe().

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Jika dilihat terdapat banyak informasi yang berisikan NaN. Untuk mengetahui mengapa hal ini bisa terjadi kita perlu melihat terlebih dahulu contoh data dari tabel customers_df dengan menggunakan fungsi sample().

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 84462  df588ce67754db0b4de1ed8c73bbeab6  c08ea6258b493d6e3d11bcdb6bd2c4c3
# 44982  acf88257f23504358aaf7f4a2ac091c5  613fd694ef74d71ea8d074507f73c4ed
# 56395  45aa60acb5f87544e19b278e6955e451  690f0991927602fa4dbe5cb1fea83794
# 53499  403e3939144e4e8f0d0bece178186f2a  63af55307fe5360d1005f03999b261e7
# 27202  ba3ed9938cfdcf9b004312a8dae52dfe  be4c3fb588f873a5c6b7e0127f1ec1ff
#
#        customer_zip_code_prefix   customer_city customer_state
# 84462                     91040    porto alegre             RS
# 44982                     74210         goiania             GO
# 56395                     11030          santos             SP
# 53499                     12704        cruzeiro             SP
# 27202                     22620  rio de janeiro             RJ

# %% [markdown]
# Jika dilihat dari sample di atas maka wajar jika terdapat banyak elemen dari ringkasan statistik bernilai NaN karena data dari masing-masing atributnya bernilai object. Selanjutnya kita coba lihat sebaran demografi pelanggan berdasarkan customer_city dan customer_state.

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Didapatkan kesimpulan bahwa kota **Sao Paulo** merupakan kota dengan total **pelanggan terbanyak sebesar 15.540 pengguna** yang kemudian disusul oleh kota Rio de Janeiro dengan total pelanggan sebanyak 6.882 pelanggan. Sementara beberapa kota lainnya seperti Lagoao, Rio dos Cedros, Rio dos Indios, dan lain-lain merupakan kota dengan jumlah pelanggan yang sedikit dengan hanya total **1 pelanggan.**
#
# Selanjutnya kita akan melihat jumlah pelanggan berdasarkan negara bagian.

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# Dapat dilihat bahwa jumlah pelanggan terbanyak terdapat pada negara bagian dengan kode **SP** yang memiliki pelanggan aktif **sebanyak 41.746 pelanggan** sementara jumlah pelanggan paling sedikit terdapat pada negara bagian dengan kode **RR** yang memiliki pelanggan aktif sebanyak **46 pelanggan**.

# %% [markdown]
# ### 2.2 Explore Tabel order_payments_df
#
# Selanjutnya kita akan mengeskplorasi tabel order_payments_df yang memuat banyak informasi mengenai pembayaran yang dilakukan. Sebagai langkah awal dalam melakukan exploratory data analysis kita akan melihat ringkasan statistik dari tabel order_payments_df. Sebelum memulai kita dapat melihat terlebih dahulu sampel data dari tabel order_payments_df.

# %%
order_payments_df.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 60482  3b580f556a4a7d02c2ce65505bb164fb                   1  credit_card
# 56018  5c8cd93d3a115eb002c7d3c40ab4fe36                   1  credit_card
# 538    dd3d73f70b77e2a07f64360620621ca4                   1  credit_card
# 62490  aadf5fc042b64c57d336c1ad8a28a455                   1  credit_card
# 37078  a3069ca25adcd219ca2358ca58f46bdc                   1  credit_card
#
#        payment_installments  payment_value
# 60482                     2        1120.84
# 56018                     1          18.93
# 538                       5         262.94
# 62490                     5         412.76
# 37078                     7          77.89

# %%
order_payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
repeat_order = order_payments_df.order_id.count() - order_payments_df.order_id.nunique()

print(repeat_order)
# Out:
# 4446

# %%
order_payments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# Berdasarkan hasil dari eksplorasi ringkasan satistik di atas didapatkan beberapa insight di antaranya adalah sebagai berikut.
# - Terdapat 5 jenis pembayaran berbeda yaitu: credit card, boleto (ticket), voucher, debit card, dan not defined.
# - Credit card merupakan metode pembayaran yang paling banyak digunakan yaitu sebanyak 76.505 kali sedangkan metode pembayaran yang paling sedikit digunakan adalah debit card sebanyak 1.528 kali digunakan.
# - Pembayaran angsuran (payment installments) paling singkat dilakukan sebanyak 0 angsuran dalam artian langsung dibayar lunas sedangkan paling banyak adalah 24 angsuran.
# - Terdapat sebanyak 4.446 pelanggan melakukan _repeat order_.

# %% [markdown]
# ### 2.3 Explore Tabel orders_df
#
# Selanjutnya kita akan mengeskplorasi tabel orders_df yang memuat banyak informasi mengenai pemesanan yang dilakukan. Sebagai langkah awal dalam melakukan exploratory data analysis kita akan melihat ringkasan statistik dari tabel orders_df. Sebelum memulai kita dapat melihat terlebih dahulu sampel data dari tabel orders_df.

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 16089  ce08f40b106df255b226e0cf2df6a11f  c9a2314ef1673617584d52322a94565e
# 7810   f6a07e6a18874c03db78033d90a50648  6d0f452f154628992e07aa608810f082
# 28527  f3d17c77cd1914628822564052e6ca02  c8f78f88ea8bf631b30486cc12f95410
# 38222  65b9d1326dd31ba17bd31dd467acb777  84bc99d4fa96340d94e6adce31619cb0
# 89695  147074da5c33b8ae783b73d181b9f141  d9368da1704624dbf1523c1fd9b8a487
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 16089    delivered      2017-11-20 11:46:00 2017-11-20 12:07:34
# 7810     delivered      2018-02-04 08:17:12 2018-02-04 08:30:22
# 28527    delivered      2017-09-27 18:16:33 2017-09-27 18:35:16
# 38222    delivered      2018-01-12 20:44:17 2018-01-12 20:56:27
# 89695    delivered      2017-04-22 16:27:13 2017-04-22 16:41:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 16089          2017-11-22 18:26:55           2017-11-24 23:57:43
# ...

# %%
# Membuat satu atribut baru bernama 'delivered_on_time' yang berisi informasi mengenai status paket yang sudah diterima
# apakah paket tersebut datang terlambat atau tepat waktu

orders_df['delivered_on_time'] = np.where(orders_df.order_delivered_customer_date <= orders_df.order_estimated_delivery_date, 'Arrived On Time', 'Late')

# %%
orders_df.describe(include="all", datetime_is_numeric=True)
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         99441                          99441
# ...

# %%
orders_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %%
orders_df.groupby(by="delivered_on_time").order_id.nunique().sort_values(ascending=False)
# Out:
# delivered_on_time
# Arrived On Time    88649
# Late               10792
# Name: order_id, dtype: int64

# %% [markdown]
# Berdasarkan hasil dari eksplorasi di atas didapatkan beberapa insight di antaranya adalah sebagai berikut.
# - Terdapat sebanyak **99.441 total order yang telah dilakukan** di mana sebanyak **96.478 order berhasil terkirim dan diterima oleh pelanggan**, 1.107 order sedang berada di dalam perjalanan (kurir), 625 order dibatalkan pesanannya, 609 order tidak  tersedia, 314 order telah dibuatkan invoice dan siapuntuk dikirim, 301 paket sedang memasuki tahap proses pembuatan invoice, 5 order telah dibuat, dan 2 pesanan sudah disetujui untuk dilanjutkan ke proses selanjutnya.
# - Sebanyak **88.649 order telah diterima oleh pelanggan dan sampai tepat waktu**. Dalam artian pelanggan menerima barang pesanan mereka sesuai dari waktu yang telah diestimasikan atau bahkan datang lebih cepat dari waktu estimasi.

# %% [markdown]
# ### 2.4 Explore Korelasi Antar Tabel
#
# #### 2.4.1 Tabel customers_df dan Tabel orders_df
#
# Selanjutnya kita akan mengeskplorasi korelasi dari dua buah tabel yaitu antara tabel customers_df dan tabel orders_df. Untuk menggabungkan dua buah tabel dapat digunakan konsep **LEFT JOIN** dengan memanfaatkan fungsi merge. Gunakan customer_id yang merupakan primary key dari tabel customers_df dan tabel orders_df.

# %%
customers_orders_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)

customers_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# #### 2.4.2 Tabel payments_df dan Tabel reviews_df
#
# Selanjutnya kita akan mengeskplorasi korelasi dari dua buah tabel yaitu antara tabel order_payments_df dan tabel order_reviews_df. Untuk menggabungkan dua buah tabel dapat digunakan konsep **LEFT JOIN** dengan memanfaatkan fungsi merge. Gunakan order_id yang merupakan primary key dari tabel order_payments_df dan tabel order_reviews_df.

# %%
payments_review_df = pd.merge(
    left=order_payments_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

payments_review_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %%
payments_review_df.sort_values(by="payment_value", ascending=False).head()
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
#
#        payment_installments  payment_value                         review_id  \
# 52415                     1       13664.08  211fa81a22870cc634265ea85b751e40
# 34565                     1        7274.88  6b9a600f1bb824da4ca38f65baf42526
# 41660                     8        6929.31  e2fbd9f0ef7b724c7ecb351601a857e7
# 49871                     1        6922.21                               NaN
# 86018                     1        6726.66  1b73e6c7cd135008ebeb18404b776ddc
#
#        review_score review_comment_title  \
# ...

# %%
payments_review_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value": ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# #### 2.4.3 Tabel customers_orders_df dan Tabel payments_df
#
# Masih dengan menggunakan **LEFT JOIN**, selanjutnya kita akan menggabungkan tabel yang sebelumnya telah digabung (tabel customers_orders_df) dengan tabel order_payments_df dengan menggunakan atribut order_id sebagai primary key dari kedua tabel tersebut.

# %%
merged_customers_df = pd.merge(
    left=customers_orders_df,
    right=order_payments_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

merged_customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# #### 2.4.3 Tabel order_items_df dan Tabel sellers_df
#
# Masih dengan menggunakan **LEFT JOIN**, selanjutnya kita akan menggabungkan tabel order_items_df dan tabel sellers_df dengan menggunakan atribut seller_id sebagai primary key dari kedua tabel tersebut.

# %%
items_sellers_df = pd.merge(
    left=order_items_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)

items_sellers_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
items_sellers_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head()
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# Name: seller_id, dtype: int64

# %%
items_sellers_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head()
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# Name: seller_id, dtype: int64

# %% [markdown]
# #### 2.4.4 Tabel products_df dan Tabel product_category_df
#
# Masih dengan menggunakan **LEFT JOIN**, selanjutnya kita akan menggabungkan tabel products_df dan tabel product_category_df dengan menggunakan atribut product_category_name sebagai primary key dari kedua tabel tersebut.

# %%
product_and_category_df = pd.merge(
    left=products_df,
    right=product_category_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)

product_and_category_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %%
product_and_category_df.drop('product_category_name', axis=1, inplace=True)

# %%
product_and_category_df.sample(5)
# Out:
#                              product_id product_category_name_english
# 3876   786beca54c998fdceea61e0a80250abf                    housewares
# 4995   f399bbedb1d21192dffefc4a8b30a229                    housewares
# 27565  c415aad99ee06e0fe8a58c09d3598ef7                 health_beauty
# 359    457c5f8a59156ce6315753d8d788a16a                 watches_gifts
# 5768   5862da8a8a08881304fe2dc5d8671200                  garden_tools

# %% [markdown]
# #### 2.4.5 Tabel product_and_category_df dan Tabel sellers_order_df
#
# Masih dengan menggunakan **LEFT JOIN**, selanjutnya kita akan menggabungkan tabel yang sebelumnya sudah digabungkan yaitu tabel product_and_category_df dengan tabel sellers_order_df dengan menggunakan product_id sebagai primary key dari kedua tabel tersebut.

# %%
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers_order_df = pd.merge(
    left=product_and_category_df, 
    right=items_sellers_df, 
    how="left", 
    left_on="product_id", 
    right_on="product_id"
)

sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers_order_df.sort_values(by="price", ascending=False).head()
# Out:
#                              product_id product_category_name_english  \
# 20528  489ae2aa008f021502940f251d4cce7f                    housewares
# 73922  69c590f7ffc7bf8db97190b6cb6ed62e                     computers
# 49503  1bdf5e6731585cf01aa8169c7028d6ad                           art
# 71835  a6492cc69376c469ab6f61d8f44de961              small_appliances
# 32232  c3ed642d592594bb648ff4a04cee2747              small_appliances
#
#                                order_id  order_item_id  \
# 20528  0812eb902a67711a1cb742b3cdaa65ae              1
# 73922  fefacc66af859508bf1a7934eab1e97f              1
# 49503  f5136e38d1a14a4dbd87dff67da82701              1
# 71835  a96610ab360d42a2e5335a3998b4718a              1
# 32232  199af31afc78c699f0dbf71fb178d4d4              1
#
#                               seller_id shipping_limit_date   price  \
# 20528  e3b4998c7a498169dc7bce44e6bb6277 2017-02-16 20:37:36  6735.0
# 73922  80ceebb4ee9b31afb6c6a916a574a1e2 2018-08-02 04:05:13  6729.0
# ...

# %%
sellers_order_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price": ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# #### 2.4.5 Tabel geolocation_df
#
# Selanjutnya kita akan mengeksplorasi tabel geolocation_df yang sudah melalui tahap pembersihan dan penilaian tabel.

# %%
geolocation_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 549343                        30315       -19.954129       -43.927158
# 165637                         6501       -23.444469       -46.917324
# 309355                        13400       -22.724426       -47.647296
# 855788                        82320       -25.401357       -49.361107
# 77480                          4184       -23.645070       -46.599061
#
#            geolocation_city geolocation_state
# 549343       belo horizonte                MG
# 165637  santana de parnaiba                SP
# 309355           piracicaba                SP
# 855788             curitiba                PR
# 77480             sao paulo                SP

# %%
geolocation_df.groupby(by="geolocation_zip_code_prefix").size().sort_values(ascending=False).head()
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
# dtype: int64

# %% [markdown]
# **CATATAN**: Fungsi size() akan enghitung jumlah entri (baris) dalam setiap grup yang dihasilkan oleh groupby. Ini mirip dengan menghitung jumlah baris dengan metode .count(), tetapi .size() menghitung semua baris dalam grup, bahkan jika ada nilai NaN di kolom lainnya sehingga fungsi ini diperlukan agar sort_values() dapat digunakan.

# %% [markdown]
# #### 2.4.6 Gabungkan dan Eksplor Semua Tabel
#
# Setelah melakukan eksplorasi terhadap semua tabel yang ada selanjutnya adalah menggabungkan semua tabel yang tersedia agar dapat dilakukan visualisasi data dan dapat dilakukan explanatory data.

# %%
all_data_df = pd.merge(
    left=merged_customers_df, 
    right=sellers_order_df, 
    how="left", 
    left_on="order_id", 
    right_on="order_id"
)

all_data_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
all_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118434 entries, 0 to 118433
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    118434 non-null  object
#  1   customer_unique_id             118434 non-null  object
#  2   customer_zip_code_prefix       118434 non-null  int64
#  3   customer_city                  118434 non-null  object
#  4   customer_state                 118434 non-null  object
#  5   order_id                       118434 non-null  object
#  6   order_status                   118434 non-null  object
#  7   order_purchase_timestamp       118434 non-null  datetime64[ns]
#  8   order_approved_at              118258 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   116360 non-null  datetime64[ns]
#  10  order_delivered_customer_date  115037 non-null  datetime64[ns]
# ...

# %%
all_data_df.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 41746     7673188.55
# RJ                 12852     2783724.26
# MG                 11635     2341861.47
# RS                  5466     1152019.17
# PR                  5045     1074614.19
# BA                  3380      802416.72
# SC                  3637      799135.92
# GO                  2020      516182.51
# DF                  2140      434512.55
# ES                  2033      406946.26
# PE                  1652      378887.48
# CE                  1336      347678.36
# PA                   975      262433.11
# MT                   907      257447.65
# MA                   747      199913.56
# PB                   536      181546.00
# MS                   715      165861.46
# PI                   495      137077.67
# RN                   485      117074.43
# AL                   413      111993.78
# SE                   350       90651.44
# TO                   280       72412.08
# ...

# %%
all_data_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_value
# product_category_name_english
# bed_bath_table                     9417     1712553.67
# health_beauty                      8836     1657373.12
# computers_accessories              6689     1585330.45
# furniture_decor                    6449     1430176.39
# watches_gifts                      5624     1429216.68
# ...                                 ...            ...
# flowers                              29        2213.01
# home_comfort_2                       24        1710.54
# cds_dvds_musicals                    12        1199.43
# fashion_childrens_clothes             8         785.67
# security_and_services                 2         324.51
#
# [71 rows x 2 columns]

# %%
all_data_df.to_csv('all_data.csv', index=False)

# %% [markdown]
# ## 3. Visualization and Explanatory Data Analysis

# %% [markdown]
# ### 3.1 Pertanyaan 1: Produk manakah yang paling laris di pasaran sehingga dapat memberikan keuntungan yang banyak bagi perusahaan?
#
# Untuk mengetahui produk mana yang paling laris di pasaran kita perlu menghitung produk yang sudah terjual. Kita dapat menghitung berdasarkan product_category_name_english agar dapat mudah dipahami karena atribut tersebut merupakan terjemahan dari bahasa Brazil ke bahasa Inggris.

# %% [markdown]
# ### 3.1.1 Berdasarkan Kategori

# %%
sum_order_items_df = all_data_df.groupby(by="product_category_name_english", as_index=False).agg({
    "product_id": "count",
    "price": "sum"
})

sum_order_items_df = sum_order_items_df.rename(columns={"product_id": "products", "price": "total_sales"})
sum_order_items_df = sum_order_items_df.sort_values(by="products", ascending=False)

sum_order_items_df.head()
# Out:
#    product_category_name_english  products  total_sales
# 7                 bed_bath_table     11823   1092551.02
# 43                 health_beauty      9975   1297490.77
# 65                sports_leisure      8945   1023996.34
# 39               furniture_decor      8744    765093.89
# 15         computers_accessories      8082    942277.57

# %%
sum_order_items_df.tail()
# Out:
#    product_category_name_english  products  total_sales
# 3          arts_and_craftmanship        24      1814.01
# 52                    la_cuisine        16      2303.98
# 11             cds_dvds_musicals        14       730.00
# 29     fashion_childrens_clothes         8       569.85
# 61         security_and_services         2       283.29

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24,6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk Paling Laris di Pasaran", loc="center", fontsize=15)
ax[0].tick_params(axis='y', labelsize=12)

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk Kurang Populer di Pasaran", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)


plt.suptitle("Perfoma Penjualan Produk Berdasarkan Kategori", fontsize=20)
plt.show()

# %% [markdown]
# ### 3.1.2 Berdasarkan Jumlah Penjualan (total_sales)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24,6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="total_sales", y="product_category_name_english", data=sum_order_items_df.sort_values(by="total_sales", ascending=False).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Penjualan Dengan Total Sales Terbesar", loc="center", fontsize=15)
ax[0].tick_params(axis='y', labelsize=12)

sns.barplot(x="total_sales", y="product_category_name_english", data=sum_order_items_df.sort_values(by="total_sales", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Penjualan Dengan Total Sales Terkecil", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)


plt.suptitle("Perfoma Penjualan Produk Berdasarkan Kategori", fontsize=20)
plt.show()

# %% [markdown]
# ### 3.2 Pertanyaan 2: Lokasi mana yang paling sering mendatangkan pelanggan yang berbelanja? Berapa total penjualan yang dihasilkan dari lokasi tersebut?

# %% [markdown]
# all_data_df.head()

# %%
# Berdasarkan customer_state

geolocation_sales_city_df = all_data_df.groupby(by="customer_city", as_index=False).agg({
    "product_id": "count",
    "price": "sum"
})

geolocation_sales_city_df = geolocation_sales_city_df.rename(columns={"product_id": "products", "price": "total_sales"})
geolocation_sales_city_df = geolocation_sales_city_df.sort_values(by="products", ascending=False)

geolocation_sales_city_df.head()
# Out:
#        customer_city  products  total_sales
# 3597       sao paulo     18590   2008254.39
# 3155  rio de janeiro      8202   1030715.84
# 453   belo horizonte      3247    366981.33
# 558         brasilia      2457    312274.57
# 1143        curitiba      1809    218532.47

# %%
geolocation_sales_state_df = all_data_df.groupby(by="customer_state", as_index=False).agg({
    "product_id": "count",
    "price": "sum"
})

geolocation_sales_state_df = geolocation_sales_state_df.rename(columns={"product_id": "products", "price": "total_sales"})
geolocation_sales_state_df = geolocation_sales_state_df.sort_values(by="products", ascending=False)

geolocation_sales_state_df.head()
# Out:
#    customer_state  products  total_sales
# 25             SP     49569   5448301.72
# 18             RJ     15327   1913564.16
# 10             MG     13638   1639636.83
# 22             RS      6486    787770.53
# 17             PR      5962    705856.47

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24,6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk Paling Laris di Pasaran", loc="center", fontsize=15)
ax[0].tick_params(axis='y', labelsize=12)

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk Kurang Populer di Pasaran", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)


plt.suptitle("Perfoma Penjualan Produk Berdasarkan Kategori", fontsize=20)
plt.show()

# %% [markdown]
# ## 4. Conclusions (Kesimpulan)
